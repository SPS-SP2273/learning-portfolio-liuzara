# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good) Exercises</span></div>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-np.pi, np.pi, num=100) #plots 100 points
cos_x = np.cos(x)
sin_x = np.sin(x)

fig, ax = plt.subplots(nrows=2, ncols=1, #the tab is for formatting
                       figsize=(5, 5), 
                       sharex = True)
ax[0].plot(x, cos_x, label=r'$\cos(x)$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].plot(x, sin_x, label=r'$\sin(x)$')
ax[1].fill_between(x, 0, np.sin(x), alpha=.25) #range of values of x, range of values of y from down up in triangles, range of values of y from up down in triangles

for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)

ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()

# %%
#ax.fill_between() general format 
# ax.fill_between(x, y1, y2, where=condition for shading, color=colour of fill, alpha=transparency, text label for shading)

# %%
import matplotlib.pyplot as plt
import numpy as np

#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8), sharex='col', sharey='row')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos(x)$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1.5, color='r', alpha=.125)

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, sin_x, -2, color='g', alpha=.125)
axes[0, 1].set_title('$\sin x$  &  $\sin^2x$')
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_xlim([np.pi,np.pi])
axes[0, 1].set_ylim(-1.25, 1.25)

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$\sin 2x$')
axes[1, 0].fill_between(x, fun1_x, -25, color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])


#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, -25, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].set_xlabel('Angle (radians)')
axes[1, 1].set_xticklabels(['$-\pi$','$-\pi/2$', '0', '$\pi/2$', '$\pi$'])

# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)
    a.legend(loc = 'upper right')
    a.set_xlim([-np.pi,np.pi])

plt.tight_layout()
plt.show(block=False) #enables editing of the graph after this point
plt.savefig('/Users/Zara/Downloads/SP2273/plots.jpg', dpi=250)
# Out:
# /var/folders/qq/y95jx0h51k78k9j6qdqv68280000gp/T/ipykernel_7756/3584807643.py:28: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   axes[0, 1].set_xlim([np.pi,np.pi])

# %%
import matplotlib.pyplot as plt
import numpy as np

variables = ['60 forward', '60 reverse', '120 forward', '120 reverse']
values = [59.33,79.33,115.67,299.67]

print(variables)
print(values)

plt.bar(variables, values)
plt.title('pipetting volumes')
plt.ylim(0.,350.)
plt.xlim(-1,4)
plt.ylabel('volume/µl')
plt.annotate('***',
            xy = (25,60), xycords='data',
            xytext=(37.5,150),textcoords='data',
            arrowprops=dict(arrowstyle='bar', fraction=0.3))

plt.show()
# Out:
# ['60 forward', '60 reverse', '120 forward', '120 reverse']
# [59.33, 79.33, 115.67, 299.67]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 15
#      13 plt.xlim(-1,4)
#      14 plt.ylabel('volume/µl')
# ---> 15 plt.annotate('***',
#      16             xy = (25,60), xycords='data',
#      17             xytext=(37.5,150),textcoords='data',
#      18             arrowprops=dict(arrowstyle='bar', fraction=0.3))
#      20 plt.show()
#
# File ~/Downloads/SP2273/GitHub/learning-portfolio-liuzara/.conda/lib/python3.11/site-packages/matplotlib/pyplot.py:2898, in annotate(text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    2887 @_copy_docstring_and_deprecators(Axes.annotate)
#    2888 def annotate(
#    2889     text: str,
#    (...)   2896     **kwargs,
#    2897 ) -> Annotation:
# -> 2898     return gca().annotate(
#    2899         text,
#    2900         xy,
#    2901         xytext=xytext,
#    2902         xycoords=xycoords,
#    2903         textcoords=textcoords,
#    2904         arrowprops=arrowprops,
#    2905         annotation_clip=annotation_clip,
#    2906         **kwargs,
#    2907     )
#
# File ~/Downloads/SP2273/GitHub/learning-portfolio-liuzara/.conda/lib/python3.11/site-packages/matplotlib/axes/_axes.py:721, in Axes.annotate(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#     716 @_docstring.interpd
#     717 def annotate(self, text, xy, xytext=None, xycoords='data', textcoords=None,
#     718              arrowprops=None, annotation_clip=None, **kwargs):
#     719     # Signature must match Annotation. This is verified in
#     720     # test_annotate_signature().
# --> 721     a = mtext.Annotation(text, xy, xytext=xytext, xycoords=xycoords,
#     722                          textcoords=textcoords, arrowprops=arrowprops,
#     723                          annotation_clip=annotation_clip, **kwargs)
#     724     a.set_transform(mtransforms.IdentityTransform())
#     725     if kwargs.get('clip_on', False) and a.get_clip_path() is None:
#
# File ~/Downloads/SP2273/GitHub/learning-portfolio-liuzara/.conda/lib/python3.11/site-packages/matplotlib/text.py:1852, in Annotation.__init__(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    1850         for key in ['width', 'headwidth', 'headlength', 'shrink']:
#    1851             arrowprops.pop(key, None)
# -> 1852     self.arrow_patch = FancyArrowPatch((0, 0), (1, 1), **arrowprops)
#    1853 else:
#    1854     self.arrow_patch = None
#
# File ~/Downloads/SP2273/GitHub/learning-portfolio-liuzara/.conda/lib/python3.11/site-packages/matplotlib/patches.py:4270, in FancyArrowPatch.__init__(self, posA, posB, path, arrowstyle, connectionstyle, patchA, patchB, shrinkA, shrinkB, mutation_scale, mutation_aspect, **kwargs)
#    4267 kwargs.setdefault("joinstyle", JoinStyle.round)
#    4268 kwargs.setdefault("capstyle", CapStyle.round)
# -> 4270 super().__init__(**kwargs)
#    4272 if posA is not None and posB is not None and path is None:
#    4273     self._posA_posB = [posA, posB]
#
# File ~/Downloads/SP2273/GitHub/learning-portfolio-liuzara/.conda/lib/python3.11/site-packages/matplotlib/patches.py:99, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      96 self.set_joinstyle(joinstyle)
#      98 if len(kwargs):
# ---> 99     self._internal_update(kwargs)
#
# File ~/Downloads/SP2273/GitHub/learning-portfolio-liuzara/.conda/lib/python3.11/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~/Downloads/SP2273/GitHub/learning-portfolio-liuzara/.conda/lib/python3.11/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: FancyArrowPatch.set() got an unexpected keyword argument 'fraction'
